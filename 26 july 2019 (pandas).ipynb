# %% [markdown]
# # day no:4
# # date : 26 july 2019

# %% [markdown]
# # problem No : 1
# # problem statement : Compute the total number of unique apps from the dataset

# %%
import pandas as pd 
df = pd.DataFrame({"A":[-5, 8, 12, None, 5, 3],  
                   "B":[-1, None, 6, 4, None, 3], 
                   "C":["anand", "ramu", "sai", "none", "jhanu", "ajay"]}) 
df
# Out:
#       A    B      C
# 0  -5.0 -1.0  anand
# 1   8.0  NaN   ramu
# 2  12.0  6.0    sai
# 3   NaN  4.0   none
# 4   5.0  NaN  jhanu
# 5   3.0  3.0   ajay

# %%
df.count(axis = 0)
# Out:
# A    5
# B    4
# C    6
# dtype: int64

# %%
import pandas as pd
a=pd.read_csv(r"C:\\Users\\Admin\\Downloads\\applestore.csv")
a.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
a.count(axis=0)
# Out:
# id                  7197
# track_name          7197
# size_bytes          7197
# currency            7197
# price               7197
# rating_count_tot    7197
# rating_count_ver    7197
# user_rating         7197
# user_rating_ver     7197
# ver                 7197
# cont_rating         7197
# prime_genre         7197
# sup_devices.num     7197
# ipadSc_urls.num     7197
# lang.num            7197
# vpp_lic             7197
# dtype: int64

# %%
a[['track_name']]
# Out:
#                                              track_name
# 0                                       PAC-MAN Premium
# 1                             Evernote - stay organized
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...
# 4                                                 Bible
# 5                                      Shanghai Mahjong
# 6                PayPal - Send and request money safely
# 7                               Pandora - Music & Radio
# 8                           PCalc - The Best Calculator
# 9                                           Ms. PAC-MAN
# 10                            Solitaire by MobilityWare
# 11                                     SCRABBLE Premium
# 12                 Google – Search made just for mobile
# 13                     Bank of America - Mobile Banking
# 14                                             FreeCell
# 15               TripAdvisor Hotels Flights Restaurants
# ...

# %% [markdown]
# # problem no : 2
# # problem statement : Print the Top 10 apps along with their rating based on the number of downloads(rating_count_tot)

# %%
z=a.sort_values("rating_count_tot",ascending=False)
z.head(10)
# Out:
#              id               track_name  size_bytes currency  price  \
# 16    284882215                 Facebook   389879808      USD    0.0
# 519   389801252                Instagram   113954816      USD    0.0
# 1346  529479190           Clash of Clans   116476928      USD    0.0
# 707   420009108               Temple Run    65921024      USD    0.0
# 7     284035177  Pandora - Music & Radio   130242560      USD    0.0
# 755   429047995                Pinterest    74778624      USD    0.0
# 4     282935706                    Bible    92774400      USD    0.0
# 1493  553834731         Candy Crush Saga   222846976      USD    0.0
# 178   324684580            Spotify Music   132510720      USD    0.0
# 275   343200656              Angry Birds   175966208      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 16             2974676               212          3.5              3.5
# ...

# %% [markdown]
# # problem no : 3
# # Categorise the dataset based on content rating into the following
# ## (i).Number of apps with content rating 4+
# ## (ii).Number of apps with content rating 9+
# ## (iii).Number of apps with content rating 12+
# ## (iv).Number of apps with content rating 17+

# %%
count=0
k=a[a.cont_rating=="4+"]
#print(len(k))
for i in k.cont_rating:
    count=count+1
print(count)
# Out:
# 4433

# %%
count=0
k=a[a.cont_rating=="9+"]
for i in k.cont_rating:
    count=count+1
print(count)
#print(k)
# Out:
# 987

# %%
count=0
k=a[a.cont_rating=="12+"]
for i in k.cont_rating:
    count=count+1
print(count)
#print(k)
# Out:
# 1155

# %%
count=0
k=a[a.cont_rating=="17+"]
for i in k:
    count=count+1
print(count)
# Out:
# 16

# %% [markdown]
# # Using the Matplotlib library, generate a Pie Chart to categorise student marks data in a CSV file into Distinction, First Class, Second Class, Third Class and Failed Categories(based on percentages). Explode the Distinction category.
# ## Generate a CSV containing marks of 2000 students
# ## From the CSV, generate the Pie Chart

# %%
import matplotlib.pyplot as plt
annu=  pd.read_csv('C:\\Users\\Admin\\Downloads\\students.csv')

colors = ["r","y","b","g"]
plt.pie(slices, labels = activities, colors=colors,  
        startangle=90, shadow = True, explode = (0, 0, 0.1, 0), 
        radius = 1.2, autopct = '%1.1f%%)
plt.title("First Class, Second Class, Third Class and Failed Categories")
plt.show()
# Out:
#   File "<ipython-input-37-bd3a428a3961>", line 7
#     radius = 1.2, autopct = '%1.1f%%)
#                                      ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # day no:5
# # date : 27 july 2019¶

# %%
import pandas as pd
movie=pd.read_table(r"http://bit.ly/movieusers")
movie.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
b=pd.read_table(r"http://bit.ly/movieusers",sep="|")
b.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
b=pd.read_table(r"http://bit.ly/movieusers",sep="|",header=None)
b.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
b=pd.read_table(r"http://bit.ly/movieusers",sep="|",usecols=[1,3])
b.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    24  technician
# 0  53       other
# 1  23      writer
# 2  24  technician
# 3  33       other
# 4  42   executive

# %%
df
# Out:
#       A    B      C
# 0  -5.0 -1.0  anand
# 1   8.0  NaN   ramu
# 2  12.0  6.0    sai
# 3   NaN  4.0   none
# 4   5.0  NaN  jhanu
# 5   3.0  3.0   ajay

# %%
df.fillna("anand")
# Out:
#        A      B      C
# 0     -5     -1  anand
# 1      8  anand   ramu
# 2     12      6    sai
# 3  anand      4   none
# 4      5  anand  jhanu
# 5      3      3   ajay

# %%
df.fillna(method="ffill")
# Out:
#       A    B      C
# 0  -5.0 -1.0  anand
# 1   8.0 -1.0   ramu
# 2  12.0  6.0    sai
# 3  12.0  4.0   none
# 4   5.0  4.0  jhanu
# 5   3.0  3.0   ajay

# %%
df.fillna(method="bfill")
# Out:
#       A    B      C
# 0  -5.0 -1.0  anand
# 1   8.0  6.0   ramu
# 2  12.0  6.0    sai
# 3   5.0  4.0   none
# 4   5.0  3.0  jhanu
# 5   3.0  3.0   ajay
